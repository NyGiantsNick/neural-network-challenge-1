# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential, save_model, load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
#Checking how much data is in Dataframe
loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   payment_history         1599 non-null   float64
#  1   location_parameter      1599 non-null   float64
#  2   stem_degree_score       1599 non-null   float64
#  3   gpa_ranking             1599 non-null   float64
#  4   alumni_success          1599 non-null   float64
#  5   study_major_code        1599 non-null   float64
#  6   time_to_completion      1599 non-null   float64
#  7   finance_workshop_score  1599 non-null   float64
#  8   cohort_ranking          1599 non-null   float64
#  9   total_loan_score        1599 non-null   float64
#  10  financial_aid_score     1599 non-null   float64
#  11  credit_ranking          1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df['credit_ranking']

# Display a sample of y
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns='credit_ranking')

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler().fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = scaler.transform(X_train)

# Fit the scaler to the features testing dataset
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_nodes = len(X.columns)
# Review the number of features
input_nodes
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
output_nodes = 1

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(tf.keras.layers.Dense(hidden_nodes_layer1, activation='relu', input_dim=input_nodes))

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(hidden_nodes_layer2, activation='relu'))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(output_nodes, activation='sigmoid'))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 3)                 21
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 5ms/step - loss: 0.6949 - accuracy: 0.5555
# Epoch 2/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6825 - accuracy: 0.5972
# Epoch 3/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6730 - accuracy: 0.6122
# Epoch 4/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6617 - accuracy: 0.6405
# Epoch 5/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6493 - accuracy: 0.6455
# Epoch 6/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6564
# Epoch 7/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6221 - accuracy: 0.6714
# Epoch 8/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6081 - accuracy: 0.6831
# Epoch 9/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5936 - accuracy: 0.7064
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f'Loss: {model_loss}, Accuracy:{model_accuracy}')
# Out:
# 13/13 - 0s - loss: 0.5132 - accuracy: 0.7450 - 180ms/epoch - 14ms/step
# Loss: 0.5132018327713013, Accuracy:0.7450000047683716

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
model_file_path = 'C:\\Users\\nicks\\OneDrive\\Desktop\\Coding\\Challenge_Files\\neural-network-1\\neural-network-challenge-1\\student_loans.keras'

# Export your model to a keras file
save_model(nn_model, model_file_path)
print(f'Model saved successfully as', model_file_path)
# Out:
# Model saved successfully as C:\Users\nicks\OneDrive\Desktop\Coding\Challenge_Files\neural-network-1\neural-network-challenge-1\student_loans.keras

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
model_file_path = 'C:\\Users\\nicks\\OneDrive\\Desktop\\Coding\\Challenge_Files\\neural-network-1\\neural-network-challenge-1\\student_loans.keras'

# Load the model to a new object
loaded_nn_model = load_model(model_file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test, verbose=2)

# Display a sample of the predictions
predictions[:10]
# Out:
# 13/13 - 0s - 103ms/epoch - 8ms/step
# array([[4.2879674e-06],
#        [1.1077646e-12],
#        [5.8794653e-01],
#        [1.2024598e-09],
#        [1.4250238e-01],
#        [2.4870239e-01],
#        [4.4301488e-03],
#        [1.1207378e-22],
#        [5.8794653e-01],
#        [5.8794653e-01]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=['predictions'], data=predictions)
predictions_df['predictions'] = round(predictions_df['predictions'],0)
predictions_df
# Out:
#      predictions
# 0            0.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            0.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          0.0
# 398          0.0
# 399          0.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df['predictions'].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.86      0.62       188
#            1       0.62      0.21      0.31       212
#
#     accuracy                           0.51       400
#    macro avg       0.55      0.53      0.47       400
# weighted avg       0.56      0.51      0.46       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# Answer: To build a reccomendation system for studen loan options there are a few data fields not included in this exercise that would be helpful.
#
#
#   a. Some more student information like age, income and exisisting loans could contribute to non-payment or conversely a history of reliable repayment. This would provide data fields that would likely have a high-correlation to loan repayment.
#
#   b. Details about the different loan options available for students would be a must as that would determine what to recommend to the student.
#
#   c. Feedback and Reviews of past borrowers would be nice, again to review the options before making a recommendation to the user.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# Answer: My model for recommending student loans to students would more than likely still utilize content-based filtering as it relies on the characteristics of items (loans) and users (students) rather than historical interactions.
#
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# Answer: There would be some ethical and transparency challenges that would be involved with this type of project.
#
# a. Data Privacy and Security would be a concern when collecting any financial data, especially for any outstanding loans. Not only is that a bit of a breach of privacy but you risk the user being dishonest about their loan history and skewing their recommendation.
#
# b. There is also the issue of bias and fairness. The model might unfairly recommend less favorable options with say, high interest rates for students from certain demographics or socioeconomic backgrounds. And any model runs the risk of favoring certain groups over others leading to overall unfair outcomes.
